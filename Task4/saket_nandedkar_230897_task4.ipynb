# %%
from PIL import Image
import os
import numpy as np
import cv2
from matplotlib import pyplot as plt
import tifffile as tiff
from patchify import patchify, unpatchify
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
all_img_patches = []
folder_path = r'C:\Users\saket\Desktop\bcs\assignment4\Sound-Refine\Task4\membrane\train\image'

for filename in os.listdir(folder_path):
    print(filename)
    file_path = os.path.join(folder_path, filename)

    image = Image.open(file_path)
    image = np.array(image)

    patched_img = patchify(image, (64,64), step=64)

    for i in range(patched_img.shape[0]):
        for j in range(patched_img.shape[1]):
            one_patch_image = patched_img[i, j, :, :]
            one_patch_img = (one_patch_image.astype('float32')) / 255

            all_img_patches.append(one_patch_image)

images_n = np.array(all_img_patches)
images_n = np.expand_dims(images_n, -1)
X_train = images_n
# print(len(images_n))
# Out:
# 0.png
# 1.png
# 10.png
# 11.png
# 12.png
# 13.png
# 14.png
# 15.png
# 16.png
# 17.png
# 18.png
# 19.png
# 2.png
# 20.png
# 21.png
# 22.png
# 23.png
# 24.png
# 25.png
# 26.png
# 27.png
# 28.png
# 29.png
# 3.png
# 4.png
# 5.png
# 6.png
# 7.png
# 8.png
# 9.png

# %%
all_label_patches = []
folder_path = r'C:\Users\saket\Desktop\bcs\assignment4\Sound-Refine\Task4\membrane\train\label'
for filename in os.listdir(folder_path):
    print(filename)
    file_path = os.path.join(folder_path, filename)

    label = Image.open(file_path)
    label = np.array(label)

    patched_label = patchify(label, (64,64), step=64)

    for i in range(patched_label.shape[0]):
        for j in range(patched_label.shape[1]):
            one_patch_label = patched_label[i, j, :, :]
            one_patch_lbl = (one_patch_label.astype('float32')) / 255

            all_label_patches.append(one_patch_lbl)



labels_n = np.array(all_label_patches)
labels_n = np.expand_dims(labels_n, -1)
y_train = labels_n
# print(len(labels_n))
# Out:
# 0.png
# 1.png
# 10.png
# 11.png
# 12.png
# 13.png
# 14.png
# 15.png
# 16.png
# 17.png
# 18.png
# 19.png
# 2.png
# 20.png
# 21.png
# 22.png
# 23.png
# 24.png
# 25.png
# 26.png
# 27.png
# 28.png
# 29.png
# 3.png
# 4.png
# 5.png
# 6.png
# 7.png
# 8.png
# 9.png

# %%
all_yimg_patches = []
folder_path = r'C:\Users\saket\Desktop\bcs\assignment4\Sound-Refine\Task4\membrane\test\y_train'

for filename in os.listdir(folder_path):
    print(filename)
    file_path = os.path.join(folder_path, filename)

    yimage = Image.open(file_path)
    yimage = np.array(yimage)

    ypatched_img = patchify(yimage, (64,64), step=64)

    for i in range(ypatched_img.shape[0]):
        for j in range(ypatched_img.shape[1]):
            one_ypatch_image = ypatched_img[i, j, :, :]
            one_ypatch_img = (one_ypatch_image.astype('float32')) / 255

            all_yimg_patches.append(one_ypatch_image)

yimages_n = np.array(all_yimg_patches)
yimages_n = np.expand_dims(yimages_n, -1)
X_test = yimages_n
# print(len(yimages_n))
# Out:
# 0.png
# 1.png
# 10.png
# 11.png
# 12.png
# 13.png
# 14.png
# 15.png
# 16.png
# 17.png
# 18.png
# 19.png
# 2.png
# 20.png
# 21.png
# 22.png
# 23.png
# 24.png
# 25.png
# 26.png
# 27.png
# 28.png
# 29.png
# 3.png
# 4.png
# 5.png
# 6.png
# 7.png
# 8.png
# 9.png

# %%
all_ylabel_patches = []
folder_path = r'C:\Users\saket\Desktop\bcs\assignment4\Sound-Refine\Task4\membrane\train\label'
for filename in os.listdir(folder_path):
    print(filename)
    file_path = os.path.join(folder_path, filename)

    ylabel = Image.open(file_path)
    ylabel = np.array(ylabel)

    ypatched_label = patchify(ylabel, (64,64), step=64)

    for i in range(ypatched_label.shape[0]):
        for j in range(ypatched_label.shape[1]):
            one_ypatch_label = ypatched_label[i, j, :, :]
            one_ypatch_lbl = (one_ypatch_label.astype('float32')) / 255

            all_ylabel_patches.append(one_ypatch_lbl)



ylabels_n = np.array(all_ylabel_patches)
ylabels_n = np.expand_dims(ylabels_n, -1)
y_test = ylabels_n
# print(len(ylabels_n))
# Out:
# 0.png
# 1.png
# 10.png
# 11.png
# 12.png
# 13.png
# 14.png
# 15.png
# 16.png
# 17.png
# 18.png
# 19.png
# 2.png
# 20.png
# 21.png
# 22.png
# 23.png
# 24.png
# 25.png
# 26.png
# 27.png
# 28.png
# 29.png
# 3.png
# 4.png
# 5.png
# 6.png
# 7.png
# 8.png
# 9.png

# %%
# from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(images_n, labels_n, test_size = 0.5, random_state = 0) 
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2], 1))
y_train = np.reshape(y_train, (y_train.shape[0], y_train.shape[1], y_train.shape[2], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2], 1))
y_test = np.reshape(y_test, (y_test.shape[0], y_test.shape[1], y_test.shape[2], 1))

# %%
IMG_HEIGHT = images_n.shape[1]
IMG_WIDTH  = images_n.shape[2]
IMG_CHANNELS = images_n.shape[3]

input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Activation, MaxPool2D, Concatenate
def conv_block (input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return (x)

def max_pooling (input, num_filters):
    x = conv_block(input, num_filters)
    p = MaxPool2D((2,2))(x)

    return (x,p)

def upscaling (input, num_filters, skip_features):
    x = Conv2DTranspose(num_filters, (2,2), strides = 2, padding = "same")(input)
    x = concatenate([x, skip_features])
    x = conv_block(x, num_filters)
    return (x)

def U_NET (input_shape):
    inputs = Input(input_shape)

    s1, p1 = max_pooling(inputs, 64)
    s2, p2 = max_pooling(p1, 128)
    s3, p3 = max_pooling(p2, 256)

    b1 = conv_block(p3, 512)

    u3 = upscaling(b1, 256, s3)
    u2 = upscaling(u3, 128, s2)
    u1 = upscaling(u2, 64, s1)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(u1)
    model = Model(inputs, outputs, name="U-Net")
    return model

# %%
model = U_NET(input_shape)
model.compile(optimizer=Adam(learning_rate= 1e-3), loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "U-Net"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 64, 64, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 64, 64,    │        640 │ input_layer_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=12, batch_size=32)
# Out:
# Epoch 1/12
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 188s 3s/step - accuracy: 0.9119 - loss: 0.2049 - val_accuracy: 0.6683 - val_loss: 1.1996
# Epoch 2/12
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 177s 3s/step - accuracy: 0.9145 - loss: 0.1972 - val_accuracy: 0.6298 - val_loss: 1.1626
# Epoch 3/12
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - accuracy: 0.9163 - loss: 0.1950 - val_accuracy: 0.6145 - val_loss: 1.2448
# Epoch 4/12
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 172s 3s/step - accuracy: 0.9169 - loss: 0.1922 - val_accuracy: 0.6469 - val_loss: 1.3144
# Epoch 5/12
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 180s 3s/step - accuracy: 0.9158 - loss: 0.1956 - val_accuracy: 0.7045 - val_loss: 1.3817
# Epoch 6/12
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - accuracy: 0.9147 - loss: 0.1947 - val_accuracy: 0.5655 - val_loss: 1.2596
# Epoch 7/12
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 177s 3s/step - accuracy: 0.9209 - loss: 0.1835 - val_accuracy: 0.6474 - val_loss: 1.4633
# Epoch 8/12
# ...

# %%
#New generator with rotation and shear where interpolation that comes with rotation and shear are thresholded in masks. 
#This gives a binary mask rather than a mask with interpolated values. 
seed=24


img_data_gen_args = dict(rotation_range=90,
                     width_shift_range=0.3,
                     height_shift_range=0.3,
                     shear_range=0.5,
                     zoom_range=0.3,
                     horizontal_flip=True,
                     vertical_flip=True,
                     fill_mode='reflect')

mask_data_gen_args = dict(rotation_range=90,
                     width_shift_range=0.3,
                     height_shift_range=0.3,
                     shear_range=0.5,
                     zoom_range=0.3,
                     horizontal_flip=True,
                     vertical_flip=True,
                     fill_mode='reflect',
                     preprocessing_function = lambda x: np.where(x>0, 1, 0).astype(x.dtype)) #Binarize the output again. 

image_data_generator = ImageDataGenerator(**img_data_gen_args)
#image_data_generator.fit(X_train, augment=True, seed=seed)

batch_size= 8

image_generator = image_data_generator.flow(X_train, seed=seed, batch_size=batch_size)
valid_img_generator = image_data_generator.flow(X_test, seed=seed, batch_size=batch_size) #Default batch size 32, if not specified here

mask_data_generator = ImageDataGenerator(**mask_data_gen_args)
#mask_data_generator.fit(y_train, augment=True, seed=seed)
mask_generator = mask_data_generator.flow(y_train, seed=seed, batch_size=batch_size)
valid_mask_generator = mask_data_generator.flow(y_test, seed=seed, batch_size=batch_size)  #Default batch size 32, if not specified here

def my_image_mask_generator(image_generator, mask_generator):
    train_generator = zip(image_generator, mask_generator)
    for (img, mask) in train_generator:
        yield (img, mask)

my_generator = my_image_mask_generator(image_generator, mask_generator)

validation_datagen = my_image_mask_generator(valid_img_generator, valid_mask_generator)

steps_per_epoch = (len(X_train))//(batch_size)


history = model.fit(my_generator, validation_data=validation_datagen, 
                    steps_per_epoch=steps_per_epoch, 
                    validation_steps=steps_per_epoch, epochs=5)
# Out:
# Epoch 1/5
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 168s 673ms/step - accuracy: 0.8889 - loss: 0.2523 - val_accuracy: 0.7104 - val_loss: 1.2558
# Epoch 2/5
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 170s 707ms/step - accuracy: 0.8934 - loss: 0.2427 - val_accuracy: 0.7130 - val_loss: 0.7616
# Epoch 3/5
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 167s 695ms/step - accuracy: 0.8963 - loss: 0.2372 - val_accuracy: 0.7134 - val_loss: 1.0209
# Epoch 4/5
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 165s 687ms/step - accuracy: 0.8975 - loss: 0.2319 - val_accuracy: 0.7362 - val_loss: 1.0416
# Epoch 5/5
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 161s 671ms/step - accuracy: 0.8986 - loss: 0.2294 - val_accuracy: 0.7142 - val_loss: 0.9590
